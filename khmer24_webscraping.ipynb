# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.parse import urlencode
import re
import pandas as pd
import csv
from http.client import IncompleteRead

# %%
API_KEY = '905b68fb-01b7-46b7-b9f8-7cb2560a388a'

# %%
productName_ = []
Price_ = []
processor_ = []
ram_ = []
brand_ = []
storage_ = []
display_ = []
vga_ = []

# %%
def get_scrapeops_url(url):
    payload = {
        'api_key' : API_KEY, 
        'url' : url
        }
    proxy_url = 'https://proxy.scrapeops.io/v1/?' + urlencode(payload)
    return proxy_url

for i in range(50, 40001):
    url = get_scrapeops_url(f'https://www.khmer24.com/en/c-laptops.html?q=&ad_field=&from_ad_price=300&to_ad_price=&location=&category=laptops&sortby=&per_page={i}')
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    container = soup.findAll('li', class_ = 'item')
    for item in container:
        try:
            link = item.a['href']
            url = get_scrapeops_url(link)
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html')
            container = soup.find('div', class_ = 'col col-8')
            try:
                name = container.find('h1').text
            except Exception:
                name = None
            try:
                price = container.find(class_ = 'price').text
            except Exception:
                price = None    
            description = container.findAll('li')
            brand = description[5].text.split(':')[1]
            screensize = description[7].text.split(':')[1]
            storage = description[8].text.split(':')[1]
            ram = description[9].text.split(':')[1]
            cpu = description[10].text.split(':')[1]
            vga = description[11].text.split(':')[1]
            
            productName_.append(name)
            brand_.append(brand)
            Price_.append(price)
            display_.append(screensize)
            vga_.append(vga)
            processor_.append(cpu)
            storage_.append(storage)
            ram_.append(ram)
                
        except Exception as e:
            print(e)
# Out:
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable
# 'NoneType' object is not subscriptable

# %%
Laptop_dict = {
        'ProductName': productName_, 
        'Brand' : brand_,
        'Price': Price_,  
        'Processor': processor_, 
        'RAM': ram_, 
        'VGA': vga_,
        'Storage': storage_, 
        'Display': display_,  
    }

Laptop_dict.values()
# Out:
# dict_values([['Dell xps 13 9370', 'MacBook Pro M1 Year 2020 Grade A', 'Surface Laptop 4 Very Good Condition 99.99%', 'MacBook Pro Retina 2018 (Touch Bar) 99%', 'Asus Rog Strix G713RC (Gaming&Design) 99%', 'MacBook Air Year 2019 Grade A', 'Asus vivoBook X412F (Used-99%) ស្ដេីងស្អាត\u200bពណ៍ស្រស់ណាស់តេី😬🥶🥶', 'ASU’s TUF FX504GD (Gaming 95%)តម្លៃល្អ\u200b RAM 16GB បងបង🎉', 'Sell Asus 14X OLED Space edition 99%', 'Acer Spin 7 2in1 (5G) (Used 99%) កប់ណាស់បងបងនៅធានាពីហាងនឹងប្រអប់មួយសេតម៉ង🥶🎉', 'Lenovo ideapad 310s', 'MacBook Pro 2017 99%', 'MacBook Pro ( 15,6-inch, 2015 ) ', 'Dell XPS 9350 មួយទឹក 99%', 'Msi Modern B11M (used 98%)', 'រីករាយជាមួយ ROG Strix G18 G814JV $1899 | i9 32GB 1.5TB RTX4060 18"', 'រីករាយជាមួយ ROG Strix G18 G814JI $2199 | i9 32G 2TB RTX4070 18"', 'រីករាយជាមួយ ROG Strix G18 G814JU $1599 | i9 16G 1.5TB RTX4050 18"', 'លេខថ្មី ! 𝐌𝐒𝐈 𝟐𝟎𝟐𝟑 ប្រូមូសិន\u200b!! Katana 17 - i7 16G 1T RTX4060 17.3" $1349', 'ASUS Vivobook 14 | X1400EA', 'ASUS VivoBook S 14x OLED | S5402ZA', 'ASUS Vivobook 15 | X1500EA', 'រីករាយជាមួយ ASUS Office $359', 'MSI Cyborg 15 A12UCX | Promo ', 'MSI GF63 Thin 11SC | Promo', 'MSI Cyborg 15 A12VF | Promo ', 'MSI Modern 15 B7M | Promotion', 'Acer Aspire 3 | MX550 2GB', 'Laptop for Media Game Design Creator ', 'Acer Swift 3x 14" | I5 Max 4GB $499', 'Acer Aspire 5 Ryzen 3 99%', 'Thinkpad X1 Carbon i7 Gen8', 'MacBook Air 2019', 'Dell Inspiron 3511(Grad A) ស្តេីងស្អាត\u200b សេរីឆ្នាំថ្មី\u200b VGA ដាច់លឿន💥🎉', 'Lenovo Legion 7 (Free PS4 Controller)', 'Dell Latitude 7280 Grade A 12.5”inch ', 'Dell Precision 5510  VGA : NVIDIA Quadro M1000M 2GB up to 10GB', ' Lenovo ThinkPad X270 (6th Generation)', 'Dell Latitude 7390 ( 8th Generation ) i7 RAM 8GB SSD 256GB ', 'HP Elitebook 840 G3 Grade A', 'តម្លៃល្អ ធានាគុណភាព', '💥Promotions 💥New -HP LAPTOP 15S Core i3 10Gen /RAM: 8G/  SSD : 256G 🔥$399🔥', 'Lenovo IdeaPad Gaming 3 2022 RTX 3050', 'VIP Business Laptop Dell latitude 5430(Grad A-99%)កាលទិញថ្មី1Kជាង😍💥', 'Lenovo ThinkPad W530', 'Lenovo ideapad 700 មួយទឹក', 'Lenovo Legion Y520', '💥Promotions 💥New - Asus VivoBook X415EA - Full HD Displays - Backlit Key', 'Asus VivoBook X421E (Used-99%)រាងតូចងាយស្រួលដាក់តាមខ្លួនតែសមត្ថភាពខ្លាំងណាបងៗ🥶🥶 🎉', 'Dell Latitude E7470 / Core i7 / Ram: 8G / SSD : 256G 💥$330💥specs as below:'], ['Dell', 'Apple', 'Microsoft', 'Apple', 'Asus', 'Apple', 'Asus', 'Asus', 'Asus', 'Acer', 'Lenovo', 'Apple', 'Apple', 'Dell', 'MSI', 'Asus', 'Asus', 'Asus', 'MSI', 'Asus', 'Asus', 'Asus', 'Asus', 'MSI', 'MSI', 'MSI', 'MSI', 'Acer', 'Asus', 'Acer', 'Acer', 'Lenovo', 'Apple', 'Dell', 'Lenovo', 'Dell', 'Dell', 'Lenovo', 'Dell', 'HP', 'Asus', 'HP', 'Lenovo', 'Dell', 'Lenovo', 'Lenovo', 'Lenovo', 'Asus', 'Asus', 'Dell'], ['$610', '$955', '$765', '$865', '$880', '$675', '$329.00', '$485.00', '$1,100', '$499.00', '$465', '$649', '$598.01', '$479', '$409', '$1,899.00', '$2,199.00', '$1,599.00', '$1,349.00', '$359.00', '$799.00', '$379.00', '$359.00', '$769.00', '$679.00', '$1,149.00', '$629.00', '$399.01', '$599.00', '$499.00', '$299.00', '$750', '$700', '$499.00', '$1,199', '$325', '$755', '$315.00', '$455', '$345', '$330', '$399', '$850', '$699.00', '$375', '$499', '$499', '$399', '$510.00', '$330'], ['Intel Core i7', 'M1', 'Intel Core i5', 'Intel Core i7', 'AMD Ryzen 7', 'Intel Core i5', 'Intel Core i3', 'Intel Core i5', 'Intel Core i7', 'Other', 'Intel Core i7', 'Intel Core i5', 'Intel Core i7', 'Intel Core i7', 'Intel Core i3', 'Intel Core i9', 'Intel Core i9', 'Intel Core i9', 'Intel Core i7', 'Intel Core i3', 'Intel Core i7', 'Intel Core i3', 'Intel Core i3', 'Intel Core i5', 'Intel Core i5', 'Intel Core i7', 'AMD Ryzen 5', 'Intel Core i3', 'Intel Core i5', 'Intel Core i5', 'AMD Ryzen 3', 'Intel Core i7', 'Intel Core i5', 'Intel Core i5', 'AMD Ryzen 7', 'Intel Core i7', 'Intel Core i7', 'Intel Core i5', 'Intel Core i7', 'Intel Core i5', 'Intel Core i5', 'Intel Core i3', 'Intel Core i5', 'Intel Core i5', 'Intel Core i7', 'Intel Core i7', 'Intel Core i5', 'Intel Core i3', 'Intel Core i5', 'Intel Core i7'], ['8GB', ' ...

# %%
df = pd.DataFrame(Laptop_dict)
df
# Out:
#                                           ProductName      Brand      Price  \
# 0                                    Dell xps 13 9370       Dell       $610
# 1                    MacBook Pro M1 Year 2020 Grade A      Apple       $955
# 2         Surface Laptop 4 Very Good Condition 99.99%  Microsoft       $765
# 3             MacBook Pro Retina 2018 (Touch Bar) 99%      Apple       $865
# 4           Asus Rog Strix G713RC (Gaming&Design) 99%       Asus       $880
# 5                       MacBook Air Year 2019 Grade A      Apple       $675
# 6   Asus vivoBook X412F (Used-99%) ស្ដេីងស្អាត​ពណ៍...       Asus    $329.00
# 7   ASU’s TUF FX504GD (Gaming 95%)តម្លៃល្អ​ RAM 16...       Asus    $485.00
# 8                Sell Asus 14X OLED Space edition 99%       Asus     $1,100
# 9   Acer Spin 7 2in1 (5G) (Used 99%) កប់ណាស់បងបងនៅ...       Acer    $499.00
# 10                                Lenovo ideapad 310s     Lenovo       $465
# 11                               MacBook Pro 2017 99%      Apple       $649
# 12                   MacBook Pro ( 15,6-inch, 2015 )       Apple    $598.01
# 13                           Dell XPS 9350 មួយទឹក 99%       Dell       $479
# 14                         Msi Modern B11M (used 98%)        MSI       $409
# 15  រីករាយជាមួយ ROG Strix G18 G814JV $1899 | i9 32...       Asus  $1,899.00
# 16  រីករាយជាមួយ ROG Strix G18 G814JI $2199 | i9 32...       Asus  $2,199.00
# 17  រីករាយជាមួយ ROG Strix G18 G814JU $1599 | i9 16...       Asus  $1,599.00
# 18  លេខថ្មី ! 𝐌𝐒𝐈 𝟐𝟎𝟐𝟑 ប្រូមូសិន​!! Katana 17 - i7...        MSI  $1,349.00
# 19                         ASUS Vivobook 14 | X1400EA       Asus    $359.00
# 20                 ASUS VivoBook S 14x OLED | S5402ZA       Asus    $799.00
